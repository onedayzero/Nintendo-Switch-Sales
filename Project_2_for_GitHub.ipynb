# %% [markdown]
# <a href="https://colab.research.google.com/github/onedayzero/Nintendo-Switch-Sales/blob/main/Project_2_for_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 2 for GitHub Portfolio
# - Clint Atterberry
# - 9 July 2022

# %%
import pandas as pd

# %% [markdown]
# # Dataset 1

# %% [markdown]
# 1) Source of data
# -  I got my data from Kaggle.com looking for 'League of Legends games'
#     - League of Legends Diamond Ranked Games (10 min)
#     - https://www.kaggle.com/datasets/bobbyscience/league-of-legends-diamond-ranked-games-10-min
#
#
# 2) Brief description of data
# - The data is statistics of almost 10,000 matches, captured at the 10 minute mark of the game. This data also includes who won the match.
#
# 3) What is the target?
# - The target is who won the match.
#
# 4) Is this a classification or regression problem?
# - This is a classification problem.
#
# 5) How many features?
# - There appears to be 39 features.
#
# 6) How many rows of data.
# - There are 9879 rows of data.
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset?
# - I see issues with having both teams data together. I may need to separate Team 1 vs Team 2.

# %%
filename1 = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vTk0zKElyn4to9BCC_ugOsTS4XK4Ne6kJENp-57gGSoxFjxfxuC14Gxgk70Xg0tOokTCjq82zrAYOTu/pub?output=csv'
df1 = pd.read_csv(filename1)
print(f'(Rows, Columns): {df1.shape}')
df1.head()
# Out:
# (Rows, Columns): (9879, 40)
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
# ...

# %% [markdown]
# # Dataset 2

# %% [markdown]
# 1) Source of data
# -  I got my data from Kaggle.com looking for 'Valorant games'
#     - Valorant Pro Matches - Full Data
#     - https://www.kaggle.com/datasets/visualize25/valorant-pro-matches-full-data
#
#
# 2) Brief description of data
# - The data is a summary of matches for pro teams from the game Valorant.
#
# 3) What is the target?
# - The target is the team won or lost.
#
# 4) Is this a classification or regression problem?
# - This is a classification problem.
#
# 5) How many features?
# - There are around 30 features.
#
# 6) How many rows of data.
# - There are 15,888 rows of data.
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset?
# - This data will need cleaning to clarify if a team won or not.

# %%
filename2 = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vRgfbORLFSODzyC5OGp0BWGWJ8VD7Vcx9DkjxBdnSgzfjxJmqAXlk-iyb8e6io3dYkjUCWtZuteOIZY/pub?output=csv'
df2 = pd.read_csv(filename2)
print(f'(Rows, Columns): {df2.shape}')
df2.head()
# Out:
# (Rows, Columns): (15888, 36)
#    GameID  MatchID     Map  Team1ID  Team2ID                Team1     Team2  \
# 0   60894    62393  Breeze     6903     6020  Booster Seat Gaming  Pho Real
# 1   60895    62393    Bind     6903     6020  Booster Seat Gaming  Pho Real
# 2   60896    62393   Haven     6903     6020  Booster Seat Gaming  Pho Real
# 3   60924    62403  Icebox     7046     7047       Bjor's Kittens  Mugiwara
# 4   60925    62403   Haven     7046     7047       Bjor's Kittens  Mugiwara
#
#                 Winner  Team1_TotalRounds  Team2_TotalRounds  ...  \
# 0  Booster Seat Gaming                 13                  7  ...
# 1             Pho Real                  2                 13  ...
# 2  Booster Seat Gaming                 13                  8  ...
# 3       Bjor's Kittens                 13                  6  ...
# 4       Bjor's Kittens                 13                  9  ...
#
#   Team1_FullBuyWon Team2_PistolWon  Team2_Eco  Team2_EcoWon  Team2_SemiEco  \
# ...
